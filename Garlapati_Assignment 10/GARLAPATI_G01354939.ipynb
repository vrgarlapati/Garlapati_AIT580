# %%
import pandas as pd

# %%
emp=pd.read_csv("D:\GMU Student\Github\Garlapati_AIT580-1\data\EmployeeAttrition.csv")

# %%
emp.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# 1. Find the number of entries/rows and columns in the data.
print("(No.of Rows, No.of Columns):",emp.shape)

#Number of Rows: 1470
# Number of Columns: 35
# Out:
# (No.of Rows, No.of Columns): (1470, 35)

# %%
# 2. What is the average Monthly Income.
print("Average Monthly Income:", emp['MonthlyIncome'].mean())
# Out:
# Average Monthly Income: 6502.931292517007

# %%
# 3. What is the highest amount of HourlyRate
print("Max Hourly Rate: ",emp['HourlyRate'].max())
# Out:
# Max Hourly Rate:  100

# %%
# 4. What is the Department, JobRole, MaritalStatus, and OverTime of EmployeeNumber “10”?
Employee_ID =10
df = emp[emp.EmployeeNumber == Employee_ID]
if not df.empty:
    print("Department: ", format(df['Department'].values[0]))
    print("JobRole: ", df['JobRole'].values[0])
    print("MaritalStatus: ", df['MaritalStatus'].values[0])
    print("OverTime: ", df['OverTime'].values[0])
else:
    print("EmployeeNumber not found: ", Emmployee_ID)
# Out:
# Department:  Research & Development
# JobRole:  Laboratory Technician
# MaritalStatus:  Married
# OverTime:  Yes

# %%
# 5. What is the Employee ID of highest MonthlyIncome paid employee?
print(emp[emp['MonthlyIncome']==emp['MonthlyIncome'].max()]['EmployeeNumber'])
# Out:
# 190    259
# Name: EmployeeNumber, dtype: int64

# %%
#Another way of finding Employee ID of highest MonthlyIncome paid employee?
print("Employee ID:", emp.iloc[emp['MonthlyIncome'].argmax()]['EmployeeNumber'])
# Out:
# Employee ID: 259

# %%
# 6. What is the Average (mean) DailyRate for all Employees Group By Age whose age is greater than 58. (hint: use groupby function)
age=emp[emp['Age']>58] #Get all rows with age > 58
print(age.groupby('Age')['DailyRate'].mean())
# Out:
# Age
# 59    992.3
# 60    833.2
# Name: DailyRate, dtype: float64

# %%
# 7. How many unique EducationField are there?
print(emp['EducationField'].unique())
print("The unique EducationField: ",len(emp['EducationField'].unique()))
# Out:
# ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# The unique EducationField:  6

# %%
# 8. What are the top 5 most common JobRole?
print(emp['JobRole'].value_counts().head(5).index.tolist())
# Out:
# ['Sales Executive', 'Research Scientist', 'Laboratory Technician', 'Manufacturing Director', 'Healthcare Representative']

# %%
# 9. How many JobRoles represented by less than 100 employees?
jr=emp['JobRole'].value_counts().sort_values()
print(jr[:3])

#JobRoles represented by less than 100 employees:
## Sales Representive: 83
## Research Director: 80
## Human Resources: 52
# Out:
# Human Resources         52
# Research Director       80
# Sales Representative    83
# Name: JobRole, dtype: int64

# %%
# 10. What is the correlation between Education and JobSatisfaction?
emp.corr()
# correlation between Education and JobSatisfaction: -0.011296
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
#Another way of finding correlation between Education and JobSatisfaction
print("Correlation between Education and JobSatisfaction:",emp['Education'].corr(emp['JobSatisfaction']))

# correlation between Education and JobSatisfaction: -0.011296116736573922
# Out:
# Correlation between Education and JobSatisfaction: -0.011296116736573922
